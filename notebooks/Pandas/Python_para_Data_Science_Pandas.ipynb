# %% [markdown]
# # <font color=green> PYTHON PARA DATA SCIENCE - PANDAS
# ---

# %% [markdown]
# # <font color=green> 1. INTRODUÇÃO AO PYTHON
# ---

# %% [markdown]
# # 1.1 Introdução

# %% [markdown]
# > Python é uma linguagem de programação de alto nível com suporte a múltiplos paradigmas de programação. É um projeto *open source* e desde seu surgimento, em 1991, vem se tornando uma das linguagens de programação interpretadas mais populares.
# >
# > Nos últimos anos Python desenvolveu uma comunidade ativa de processamento científico e análise de dados e vem se destacando como uma das linguagens mais relevantes quando o assundo é ciência de dados e machine learning, tanto no ambiente acadêmico como também no mercado.

# %% [markdown]
# # 1.2 Instalação e ambiente de desenvolvimento

# %% [markdown]
# ### Instalação Local
#
# ### https://www.python.org/downloads/
# ### ou
# ### https://www.anaconda.com/distribution/

# %% [markdown]
# ### Google Colaboratory
#
# ### https://colab.research.google.com

# %% [markdown]
# ### Verificando versão

# %%
# !python -V
# Out:
# Python 3.6.9

# %% [markdown]
# # 1.3 Trabalhando com dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
# pd.set_option('display.max_rows', 50)
# pd.set_option('display.max_columns', 10)

# %%
dataset = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Python_Data_Science/Pandas/data/db.csv', sep=';')
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
dataset.dtypes
# Out:
# Nome              object
# Motor             object
# Ano                int64
# Quilometragem    float64
# Zero_km             bool
# Acessórios        object
# Valor            float64
# dtype: object

# %%
dataset[['Quilometragem', 'Valor']].describe()
# Out:
#        Quilometragem          Valor
# count     197.000000     258.000000
# mean    58278.421320   98960.513101
# std     35836.733259   29811.932305
# min       107.000000   50742.100000
# 25%     27505.000000   70743.512500
# 50%     55083.000000   97724.380000
# 75%     90495.000000  124633.302500
# max    119945.000000  149489.920000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           258 non-null    object
#  1   Motor          258 non-null    object
#  2   Ano            258 non-null    int64
#  3   Quilometragem  197 non-null    float64
#  4   Zero_km        258 non-null    bool
#  5   Acessórios     258 non-null    object
#  6   Valor          258 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 12.5+ KB

# %% [markdown]
# # <font color=green> 2. TRABALHANDO COM TUPLAS
# ---

# %% [markdown]
# # 2.1 Criando tuplas
#
# Tuplas são sequências imutáveis que são utilizadas para armazenar coleções de itens, geralmente heterogêneos. Podem ser construídas de várias formas:
# ```
# - Utilizando um par de parênteses: ( )
# - Utilizando uma vírgula à direita: x,
# - Utilizando um par de parênteses com itens separados por vírgulas: ( x, y, z )
# - Utilizando: tuple() ou tuple(iterador)
# ```

# %%
()
# Out:
# ()

# %%
(1, 2, 3)
# Out:
# (1, 2, 3)

# %%
nome = 'Passat'
valor = 12000
(nome, valor)
# Out:
# ('Passat', 12000)

# %%
nomes_carros = tuple(['Jetta Variant', 'Passat', 'Crossfox', 'DS5'])
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
type(nomes_carros)
# Out:
# tuple

# %% [markdown]
# # 2.2 Seleções em tuplas

# %%
nomes_carros[-1]
# Out:
# 'DS5'

# %%
nomes_carros[0]
# Out:
# 'Jetta Variant'

# %%
nomes_carros[1:3]
# Out:
# ('Passat', 'Crossfox')

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4'))
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4'))

# %%
nomes_carros[4]
# Out:
# ('Fusca', 'Gol', 'C4')

# %%
nomes_carros[-1][1]
# Out:
# 'Gol'

# %% [markdown]
# # 2.3 Iterando em tuplas

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
for item in nomes_carros:
  print(item)
# Out:
# Jetta Variant
# Passat
# Crossfox
# DS5

# %% [markdown]
# ### Desempacotamento de tuplas

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']

# %%
carro_1, carro_2, carro_3, carro_4 = carros # processo parecido com destructuring do javascript
carro_1
# Out:
# 'Passat'

# %%
carro_2
# Out:
# 'Passat'

# %%
_, A, _, B = carros

# %%
A
# Out:
# 'Passat'

# %%
B
# Out:
# 'DS5'

# %% [markdown]
# ## *zip()*
#
# https://docs.python.org/3.6/library/functions.html#zip

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']

# %%
valores = [88078.64, 106161.94, 72832.16, 124549.07]
valores
# Out:
# [88078.64, 106161.94, 72832.16, 124549.07]

# %%
list(zip(carros, valores))
# Out:
# [('Jetta Variant', 88078.64),
#  ('Passat', 106161.94),
#  ('Crossfox', 72832.16),
#  ('DS5', 124549.07)]

# %%
for item in zip(carros, valores):
  print(item)
# Out:
# ('Jetta Variant', 88078.64)
# ('Passat', 106161.94)
# ('Crossfox', 72832.16)
# ('DS5', 124549.07)

# %%
for carro, valor in zip(carros, valores):
  print(carro, valor)
# Out:
# Jetta Variant 88078.64
# Passat 106161.94
# Crossfox 72832.16
# DS5 124549.07

# %%
for carro, valor in zip(carros, valores):
  if (valor > 100000):
    print(carro)
# Out:
# Passat
# DS5

# %% [markdown]
# # <font color=green> 3. TRABALHANDO COM DICIONÁRIOS
# ---

# %% [markdown]
# # 3.1 Criando dicionários
#
# Listas são coleções sequenciais, isto é, os itens destas sequências estão ordenados e utilizam índices (números inteiros) para acessar os valores.
#
# Os dicionários são coleções um pouco diferentes. São estruturas de dados que representam um tipo de mapeamento. Mapeamentos são coleções de associações entre pares de valores onde o primeiro elemento do par é conhecido como chave (*key*) e o segundo como valor (*value*).
#
# ```
# dicionario = {key_1: value_1, key_2: value_2, ..., key_n: value_n}
# ```
#
# https://docs.python.org/3.6/library/stdtypes.html#typesmapping

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
valores = [88078.64, 106161.94, 72832.16]
valores
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
carros.index('Passat')
# Out:
# 1

# %%
valores[carros.index('Passat')]
# Out:
# 106161.94

# %%
dados = {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}
dados
# Out:
# {'Crossfox': 72832.16, 'Jetta Variant': 88078.64, 'Passat': 106161.94}

# %%
type(dados)
# Out:
# dict

# %% [markdown]
# ### Criando dicionários com *zip()*

# %%
list(zip(carros, valores))
# Out:
# [('Jetta Variant', 88078.64), ('Passat', 106161.94), ('Crossfox', 72832.16)]

# %%
dados = dict(zip(carros, valores))
dados
# Out:
# {'Crossfox': 72832.16, 'Jetta Variant': 88078.64, 'Passat': 106161.94}

# %% [markdown]
# # 3.2 Operações com dicionários

# %% [markdown]
# ## *dict[ key ]*
#
# Retorna o valor correspondente à chave (*key*) no dicionário.

# %%
dados["Passat"]
# Out:
# 106161.94

# %% [markdown]
# ## *key in dict*
#
# Retorna **True** se a chave (*key*) for encontrada no dicionário.

# %%
'Passat' in dados
# Out:
# True

# %%
'Fusca' in dados
# Out:
# False

# %%
'Fusca' not in dados
# Out:
# True

# %% [markdown]
# ## *len(dict)*
#
# Retorna o número de itens do dicionário.

# %%
len(dados)
# Out:
# 3

# %% [markdown]
# ## *dict[ key ] = value*
#
# Inclui um item ao dicionário.

# %%
dados['DS5'] = 124459.07
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124459.07,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %% [markdown]
# ## *del dict[ key ]*
#
# Remove o item de chave (*key*) do dicionário.

# %%
del dados['DS5']
dados
# Out:
# {'Crossfox': 72832.16, 'Jetta Variant': 88078.64, 'Passat': 106161.94}

# %% [markdown]
# # 3.3 Métodos de dicionários

# %% [markdown]
# ## *dict.update()*
#
# Atualiza o dicionário.

# %%
dados = {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}
dados
# Out:
# {'Crossfox': 72832.16, 'Jetta Variant': 88078.64, 'Passat': 106161.94}

# %%
dados.update({'DS5': 124459.07})
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124459.07,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %%
dados.update({'DS5': 124459.90, 'Fusca': 15000.00})
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124459.9,
#  'Fusca': 15000.0,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %% [markdown]
# ## *dict.copy()*
#
# Cria uma cópia do dicionário.

# %%
dadosCopy = dados.copy()
dadosCopy
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124459.9,
#  'Fusca': 15000.0,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %%
del dadosCopy['Fusca']
dadosCopy
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124459.9,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %%
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124459.9,
#  'Fusca': 15000.0,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %% [markdown]
# ## *dict.pop(key[, default ])*
#
# Se a chave for encontrada no dicionário, o item é removido e seu valor é retornado. Caso contrário, o valor especificado como *default* é retornado. Se o valor *default* não for fornecido e a chave não for encontrada no dicionário um erro será gerado.

# %%
dadosCopy = dados.copy()
dadosCopy
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124459.9,
#  'Fusca': 15000.0,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %%
dadosCopy.pop('Fusca')
# Out:
# 15000.0

# %%
dadosCopy
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124459.9,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %%
dadosCopy.pop('Fusca')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-11c9a12d3156> in <module>()
# ----> 1 dadosCopy.pop('Fusca')
#
# KeyError: 'Fusca'

# %%
dadosCopy.pop('Fusca', 'Chave não encontrada') # tratamento de erro
# Out:
# 'Chave não encontrada'

# %% [markdown]
# ## *dict.clear()*
#
# Remove todos os itens do dicionário.

# %%
dadosCopy
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124459.9,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %%
dadosCopy.clear()
dadosCopy
# Out:
# {}

# %% [markdown]
# # 3.4 Iterando em dicionários

# %% [markdown]
# ## *dict.keys()*
#
# Retorna uma lista contendo as chaves (*keys*) do dicionário.

# %%
dados = {'Crossfox': 72832.16, 'DS5': 124459.9, 'Fusca': 15000.0, 'Jetta Variant': 88078.64, 'Passat': 106161.94}
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124459.9,
#  'Fusca': 15000.0,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %%
dados.keys()
# Out:
# dict_keys(['Crossfox', 'DS5', 'Fusca', 'Jetta Variant', 'Passat'])

# %%
for item in dados.keys():
  print(item)
# Out:
# Crossfox
# DS5
# Fusca
# Jetta Variant
# Passat

# %% [markdown]
# ## *dict.values()*
#
# Retorna uma lista com todos os valores (*values*) do dicionário.

# %%
dados.values()
# Out:
# dict_values([72832.16, 124459.9, 15000.0, 88078.64, 106161.94])

# %%
for item in dados.values():
  print(item)
# Out:
# 72832.16
# 124459.9
# 15000.0
# 88078.64
# 106161.94

# %% [markdown]
# ## *dict.items()*
#
# Retorna uma lista contendo uma tupla para cada par chave-valor (*key-value*) do dicionário.

# %%
dados.items()
# Out:
# dict_items([('Crossfox', 72832.16), ('DS5', 124459.9), ('Fusca', 15000.0), ('Jetta Variant', 88078.64), ('Passat', 106161.94)])

# %%
for item in dados.items():
  print(item)
# Out:
# ('Crossfox', 72832.16)
# ('DS5', 124459.9)
# ('Fusca', 15000.0)
# ('Jetta Variant', 88078.64)
# ('Passat', 106161.94)

# %%
for key, value in dados.items():
  print(key, value)
# Out:
# Crossfox 72832.16
# DS5 124459.9
# Fusca 15000.0
# Jetta Variant 88078.64
# Passat 106161.94

# %%
for key, value in dados.items():
  if (value > 100000):
    print(key)
# Out:
# DS5
# Passat

# %% [markdown]
# # <font color=green> 4. FUNÇÕES E PACOTES
# ---
#
# Funções são unidades de código reutilizáveis que realizam uma tarefa específica, podem receber alguma entrada e também podem retornar alguma resultado.

# %% [markdown]
# # 4.1 Built-in function
#
# A linguagem Python possui várias funções integradas que estão sempre acessíveis. Algumas já utilizamos em nosso treinamento: type(), print(), zip(), len(), set() etc.
#
# https://docs.python.org/3.6/library/functions.html

# %%
dados = {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}
dados
# Out:
# {'Crossfox': 72832.16, 'Jetta Variant': 88078.64, 'Passat': 106161.94}

# %%
sum(dados.values())
# Out:
# 267072.74

# %% [markdown]
# # 4.2 Definindo funções sem e com parâmetros

# %% [markdown]
# ### Funções sem parâmetros
#
# #### Formato padrão
#
# ```
# def <nome>():
#     <instruções>
# ```

# %%
def olaMundo():
  print('Olá mundo')
olaMundo()
# Out:
# Olá mundo

# %% [markdown]
# ### Funções com parâmetros
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
# ```

# %% [markdown]
# ### Funções que retornam um valor
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
#     return <resultado>
# ```

# %%
def media(valor1, valor2):
  return (valor1 + valor2) / 2

# %%
media(30, 10)
# Out:
# 20.0

# %%
def media(lista):
  return sum(lista) / len(lista)

# %%
media([10, 20, 30])
# Out:
# 20.0

# %% [markdown]
# # 4.3 Definindo funções que retornam valores

# %% [markdown]
# ### Funções que retornam mais de um valor
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
#     return (<resultado_1>, <resultado_2>, ..., <resultado_n>)
# ```

# %%
def media(lista):
  return ((sum(lista) / len(lista)), len(lista))

# %%
media([10, 20, 30])
# Out:
# (20.0, 3)

# %%
valor, tamanho = media([10, 20, 30])

# %%
valor
# Out:
# 20.0

# %%
tamanho
# Out:
# 3

# %% [markdown]
# # <font color=green> 5. PANDAS BÁSICO
# ---
#
# **versão: 0.25.2**
#
# Pandas é uma ferramenta de manipulação de dados de alto nível, construída com base no pacote Numpy. O pacote pandas possui estruturas de dados bastante interessantes para manipulação de dados e por isso é muito utilizado por cientistas de dados.
#
#
# ## Estruturas de Dados
#
# ### Series
#
# Series são arrays unidimensionais rotulados capazes de armazenar qualquer tipo de dado. Os rótulos das linhas são chamados de **index**. A forma básica de criação de uma Series é a seguinte:
#
#
# ```
#     s = pd.Series(dados, index = index)
# ```
#
# O argumento *dados* pode ser um dicionário, uma lista, um array Numpy ou uma constante.
#
# ### DataFrames
#
# DataFrame é uma estrutura de dados tabular bidimensional com rótulos nas linha e colunas. Como a Series, os DataFrames são capazes de armazenar qualquer tipo de dados.
#
#
# ```
#     df = pd.DataFrame(dados, index = index, columns = columns)
# ```
#
# O argumento *dados* pode ser um dicionário, uma lista, um array Numpy, uma Series e outro DataFrame.
#
# **Documentação:** https://pandas.pydata.org/pandas-docs/version/0.25/

# %% [markdown]
# # 5.1 Estruturas de dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# ### Criando uma Series a partir de uma lista

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
pd.Series(carros)
# Out:
# 0    Jetta Variant
# 1           Passat
# 2         Crossfox
# dtype: object

# %% [markdown]
# ### Criando um DataFrame a partir de uma lista de dicionários

# %%
dados = [
    {'Nome': 'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Ano': 2003, 'Quilometragem': 44410.0, 'Zero_km': False, 'Valor': 88078.64},
    {'Nome': 'Passat', 'Motor': 'Motor Diesel', 'Ano': 1991, 'Quilometragem': 5712.0, 'Zero_km': False, 'Valor': 106161.94},
    {'Nome': 'Crossfox', 'Motor': 'Motor Diesel V8', 'Ano': 1990, 'Quilometragem': 37123.0, 'Zero_km': False, 'Valor': 72832.16}
]

# %%
dataset = pd.DataFrame(dados)
dataset
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %%
dataset[['Nome', 'Ano', 'Valor']]
# Out:
#             Nome   Ano      Valor
# 0  Jetta Variant  2003   88078.64
# 1         Passat  1991  106161.94
# 2       Crossfox  1990   72832.16

# %% [markdown]
# ### Criando um DataFrame a partir de um dicionário

# %%
dados = {
    'Nome': ['Jetta Variant', 'Passat', 'Crossfox'], 
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8'],
    'Ano': [2003, 1991, 1990],
    'Quilometragem': [44410.0, 5712.0, 37123.0],
    'Zero_km': [False, False, False],
    'Valor': [88078.64, 106161.94, 72832.16]
}

# %%
dataset = pd.DataFrame(dados)
dataset
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %% [markdown]
# ### Criando um DataFrame a partir de uma arquivo externo

# %%
dataset = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Python_Data_Science/Pandas/data/db.csv', sep=';').T
dataset
# Out:
#                                                                0  ...                                                257
# Nome                                               Jetta Variant  ...                                              Macan
# Motor                                            Motor 4.0 Turbo  ...                                    Motor Diesel V6
# Ano                                                         2003  ...                                               1992
# Quilometragem                                              44410  ...                                              50188
# Zero_km                                                    False  ...                                              False
# Acessórios     ['Rodas de liga', 'Travas elétricas', 'Piloto ...  ...  ['Central multimídia', 'Teto panorâmico', 'Vid...
# Valor                                                    88078.6  ...                                            90381.5
#
# ...

# %%
dataset = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Python_Data_Science/Pandas/data/db.csv', sep=';', index_col=0)
dataset
# Out:
#                                        Motor  ...      Valor
# Nome                                          ...
# Jetta Variant                Motor 4.0 Turbo  ...   88078.64
# Passat                          Motor Diesel  ...  106161.94
# Crossfox                     Motor Diesel V8  ...   72832.16
# DS5                          Motor 2.4 Turbo  ...  124549.07
# Aston Martin DB4             Motor 2.4 Turbo  ...   92612.10
# ...                                      ...  ...        ...
# Phantom 2013                        Motor V8  ...   51759.58
# Cadillac Ciel concept               Motor V8  ...   51667.06
# Classe GLK             Motor 5.0 V8 Bi-Turbo  ...   68934.03
# Aston Martin DB5                Motor Diesel  ...  122110.90
# Macan                        Motor Diesel V6  ...   90381.47
#
# [258 rows x 6 columns]

# %% [markdown]
# # 5.2 Seleções com DataFrames

# %% [markdown]
# ### Selecionando colunas

# %%
dataset = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Python_Data_Science/Pandas/data/db.csv', sep=';', index_col=0)
dataset.head()
# Out:
#                             Motor  ...      Valor
# Nome                               ...
# Jetta Variant     Motor 4.0 Turbo  ...   88078.64
# Passat               Motor Diesel  ...  106161.94
# Crossfox          Motor Diesel V8  ...   72832.16
# DS5               Motor 2.4 Turbo  ...  124549.07
# Aston Martin DB4  Motor 2.4 Turbo  ...   92612.10
#
# [5 rows x 6 columns]

# %%
dataset['Valor']
# Out:
# Nome
# Jetta Variant             88078.64
# Passat                   106161.94
# Crossfox                  72832.16
# DS5                      124549.07
# Aston Martin DB4          92612.10
#                            ...
# Phantom 2013              51759.58
# Cadillac Ciel concept     51667.06
# Classe GLK                68934.03
# Aston Martin DB5         122110.90
# Macan                     90381.47
# Name: Valor, Length: 258, dtype: float64

# %%
type(dataset['Valor']) # dataframes são conjunto de series
# Out:
# pandas.core.series.Series

# %%
dataset[['Valor']]
# Out:
#                            Valor
# Nome
# Jetta Variant           88078.64
# Passat                 106161.94
# Crossfox                72832.16
# DS5                    124549.07
# Aston Martin DB4        92612.10
# ...                          ...
# Phantom 2013            51759.58
# Cadillac Ciel concept   51667.06
# Classe GLK              68934.03
# Aston Martin DB5       122110.90
# Macan                   90381.47
#
# [258 rows x 1 columns]

# %%
type(dataset[['Valor']]) # agora é um dataframe
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Selecionando linhas - [ i : j ]
#
# <font color=red>**Observação:**</font> A indexação tem origem no zero e nos fatiamentos (*slices*) a linha com índice i é **incluída** e a linha com índice j **não é incluída** no resultado.

# %%
dataset[0:3]
# Out:
#                          Motor  ...      Valor
# Nome                            ...
# Jetta Variant  Motor 4.0 Turbo  ...   88078.64
# Passat            Motor Diesel  ...  106161.94
# Crossfox       Motor Diesel V8  ...   72832.16
#
# [3 rows x 6 columns]

# %% [markdown]
# ### Utilizando .loc para seleções
#
# <font color=red>**Observação:**</font> Seleciona um grupo de linhas e colunas segundo os rótulos ou uma matriz booleana.

# %%
dataset.loc['Passat']
# Out:
# Motor                                                 Motor Diesel
# Ano                                                           1991
# Quilometragem                                                 5712
# Zero_km                                                      False
# Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
# Valor                                                       106162
# Name: Passat, dtype: object

# %%
dataset.loc[['Passat', 'DS5']]
# Out:
#                   Motor  ...      Valor
# Nome                     ...
# Passat     Motor Diesel  ...  106161.94
# DS5     Motor 2.4 Turbo  ...  124549.07
#
# [2 rows x 6 columns]

# %%
dataset.loc[['Passat', 'DS5'],['Motor', 'Valor']]
# Out:
#                   Motor      Valor
# Nome
# Passat     Motor Diesel  106161.94
# DS5     Motor 2.4 Turbo  124549.07

# %%
dataset.loc[:,['Motor', 'Valor']]
# Out:
#                                        Motor      Valor
# Nome
# Jetta Variant                Motor 4.0 Turbo   88078.64
# Passat                          Motor Diesel  106161.94
# Crossfox                     Motor Diesel V8   72832.16
# DS5                          Motor 2.4 Turbo  124549.07
# Aston Martin DB4             Motor 2.4 Turbo   92612.10
# ...                                      ...        ...
# Phantom 2013                        Motor V8   51759.58
# Cadillac Ciel concept               Motor V8   51667.06
# Classe GLK             Motor 5.0 V8 Bi-Turbo   68934.03
# Aston Martin DB5                Motor Diesel  122110.90
# Macan                        Motor Diesel V6   90381.47
#
# [258 rows x 2 columns]

# %% [markdown]
# ### Utilizando .iloc para seleções
#
# <font color=red>**Observação:**</font> Seleciona com base nos índices, ou seja, se baseia na posição das informações.

# %%
dataset.iloc[1]
# Out:
# Motor                                                 Motor Diesel
# Ano                                                           1991
# Quilometragem                                                 5712
# Zero_km                                                      False
# Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
# Valor                                                       106162
# Name: Passat, dtype: object

# %%
dataset.iloc[[1]]
# Out:
#                Motor  ...      Valor
# Nome                  ...
# Passat  Motor Diesel  ...  106161.94
#
# [1 rows x 6 columns]

# %%
dataset.iloc[:, [1,2]]
# Out:
#                         Ano  Quilometragem
# Nome
# Jetta Variant          2003        44410.0
# Passat                 1991         5712.0
# Crossfox               1990        37123.0
# DS5                    2019            NaN
# Aston Martin DB4       2006        25757.0
# ...                     ...            ...
# Phantom 2013           2014        27505.0
# Cadillac Ciel concept  1991        29981.0
# Classe GLK             2002        52637.0
# Aston Martin DB5       1996         7685.0
# Macan                  1992        50188.0
#
# [258 rows x 2 columns]

# %% [markdown]
# # 5.3 Queries com DataFrames

# %%
dataset.Motor # quando rótulo sem espaço
# Out:
# Nome
# Jetta Variant                  Motor 4.0 Turbo
# Passat                            Motor Diesel
# Crossfox                       Motor Diesel V8
# DS5                            Motor 2.4 Turbo
# Aston Martin DB4               Motor 2.4 Turbo
#                                  ...
# Phantom 2013                          Motor V8
# Cadillac Ciel concept                 Motor V8
# Classe GLK               Motor 5.0 V8 Bi-Turbo
# Aston Martin DB5                  Motor Diesel
# Macan                          Motor Diesel V6
# Name: Motor, Length: 258, dtype: object

# %%
dataset.Motor == 'Motor Diesel'
# Out:
# Nome
# Jetta Variant            False
# Passat                    True
# Crossfox                 False
# DS5                      False
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5          True
# Macan                    False
# Name: Motor, Length: 258, dtype: bool

# %%
select = dataset.Motor == 'Motor Diesel'
select
# Out:
# Nome
# Jetta Variant            False
# Passat                    True
# Crossfox                 False
# DS5                      False
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5          True
# Macan                    False
# Name: Motor, Length: 258, dtype: bool

# %%
type(select)
# Out:
# pandas.core.series.Series

# %%
dataset[select].head() # do select, carro que estiver com valor true será exibido!
# Out:
#                               Motor  ...      Valor
# Nome                                 ...
# Passat                 Motor Diesel  ...  106161.94
# Effa Hafei Picape Baú  Motor Diesel  ...  125684.65
# Sorento                Motor Diesel  ...   81399.35
# New Fiesta Hatch       Motor Diesel  ...   66007.16
# Kangoo Express         Motor Diesel  ...  146716.91
#
# [5 rows x 6 columns]

# %%
select = dataset[(dataset.Motor == 'Motor Diesel') & (dataset.Zero_km == True)]
select
# Out:
#                             Motor  ...      Valor
# Nome                               ...
# Sorento              Motor Diesel  ...   81399.35
# Cielo Hatch          Motor Diesel  ...  145197.70
# Camry                Motor Diesel  ...  138597.27
# Aston Martin Virage  Motor Diesel  ...   97290.18
# Série 7 Sedã         Motor Diesel  ...   67539.79
#
# [5 rows x 6 columns]

# %%
(dataset.Motor == 'Motor Diesel') & (dataset.Zero_km == True)
# Out:
# Nome
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                      False
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5         False
# Macan                    False
# Length: 258, dtype: bool

# %% [markdown]
# ### Utilizando o método query

# %%
dataset.query('Motor == "Motor Diesel" and Zero_km == True').head()
# Out:
#                             Motor  ...      Valor
# Nome                               ...
# Sorento              Motor Diesel  ...   81399.35
# Cielo Hatch          Motor Diesel  ...  145197.70
# Camry                Motor Diesel  ...  138597.27
# Aston Martin Virage  Motor Diesel  ...   97290.18
# Série 7 Sedã         Motor Diesel  ...   67539.79
#
# [5 rows x 6 columns]

# %% [markdown]
# # 5.4 Iterando com DataFrames

# %%
for item in dataset: # retornará apenas os rótulos
  print(item)
# Out:
# Motor
# Ano
# Quilometragem
# Zero_km
# Acessórios
# Valor

# %%
# trazendo as 03 primeiras linhas
# retorna tuplas, com "índice, Serie"
list(dataset.iterrows())[:3]
# Out:
# [('Jetta Variant',
#   Motor                                              Motor 4.0 Turbo
#   Ano                                                           2003
#   Quilometragem                                                44410
#   Zero_km                                                      False
#   Acessórios       ['Rodas de liga', 'Travas elétricas', 'Piloto ...
#   Valor                                                      88078.6
#   Name: Jetta Variant, dtype: object),
#  ('Passat', Motor                                                 Motor Diesel
#   Ano                                                           1991
#   Quilometragem                                                 5712
#   Zero_km                                                      False
#   Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
#   Valor                                                       106162
#   Name: Passat, dtype: object),
#  ('Crossfox',
# ...

# %%
for index, row in dataset.iterrows():
  if(2019 - row['Ano'] != 0):
    dataset.loc[index, 'km_media'] = row['Quilometragem'] / (2019 - row['Ano'])
  else:
    dataset.loc[index, 'km_media'] = 0
dataset[:10]
# Out:
#                                   Motor   Ano  ...      Valor      km_media
# Nome                                           ...
# Jetta Variant           Motor 4.0 Turbo  2003  ...   88078.64   2775.625000
# Passat                     Motor Diesel  1991  ...  106161.94    204.000000
# Crossfox                Motor Diesel V8  1990  ...   72832.16   1280.103448
# DS5                     Motor 2.4 Turbo  2019  ...  124549.07      0.000000
# Aston Martin DB4        Motor 2.4 Turbo  2006  ...   92612.10   1981.307692
# Palio Weekend             Motor 1.8 16v  2012  ...   97497.73   1532.571429
# A5                      Motor 4.0 Turbo  2019  ...   56445.20      0.000000
# Série 3 Cabrio             Motor 1.0 8v  2009  ...  112310.44   7759.900000
# Dodge Jorney              Motor 3.0 32v  2010  ...  120716.27  11021.888889
# Carens            Motor 5.0 V8 Bi-Turbo  2011  ...   76566.49   4747.250000
#
# [10 rows x 7 columns]

# %% [markdown]
# # 5.5 Tratamento de dados

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, Jetta Variant to Macan
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Motor          258 non-null    object
#  1   Ano            258 non-null    int64
#  2   Quilometragem  197 non-null    float64
#  3   Zero_km        258 non-null    bool
#  4   Acessórios     258 non-null    object
#  5   Valor          258 non-null    float64
#  6   km_media       258 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 24.4+ KB

# %%
dataset.Quilometragem.isna()
# Out:
# Nome
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                       True
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5         False
# Macan                    False
# Name: Quilometragem, Length: 258, dtype: bool

# %%
dataset[dataset.Quilometragem.isna()].head()
# Out:
#                      Motor   Ano  ...      Valor  km_media
# Nome                              ...
# DS5        Motor 2.4 Turbo  2019  ...  124549.07       0.0
# A5         Motor 4.0 Turbo  2019  ...   56445.20       0.0
# J5                Motor V6  2019  ...   53183.38       0.0
# A3            Motor 1.0 8v  2019  ...   88552.39       0.0
# Série 1 M         Motor V8  2019  ...   94564.40       0.0
#
# [5 rows x 7 columns]

# %%
dataset.fillna(0, inplace=True)
dataset[dataset.Quilometragem.isna()].head()
# Out:
# Empty DataFrame
# Columns: [Motor, Ano, Quilometragem, Zero_km, Acessórios, Valor, km_media]
# Index: []

# %%
 dataset[(dataset.Quilometragem == 0)].head()
# Out:
#                      Motor   Ano  ...      Valor  km_media
# Nome                              ...
# DS5        Motor 2.4 Turbo  2019  ...  124549.07       0.0
# A5         Motor 4.0 Turbo  2019  ...   56445.20       0.0
# J5                Motor V6  2019  ...   53183.38       0.0
# A3            Motor 1.0 8v  2019  ...   88552.39       0.0
# Série 1 M         Motor V8  2019  ...   94564.40       0.0
#
# [5 rows x 7 columns]

# %%
 dataset[(dataset.Quilometragem == 0) & (dataset.Zero_km == False)].head()
 # com resultado, nota-se que não há registros com problemas no atributo quilometragem
 # dado que os zerados são carros zero km.
# Out:
# Empty DataFrame
# Columns: [Motor, Ano, Quilometragem, Zero_km, Acessórios, Valor, km_media]
# Index: []

# %%
# mas supondo que haja registros com falha em Quilometragem
dataset = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Python_Data_Science/Pandas/data/db.csv', sep=';', index_col=0)
dataset.dropna(subset=['Quilometragem'], inplace=True)
dataset[(dataset.Quilometragem == 0)].head() # registros eliminados!
# Out:
# Empty DataFrame
# Columns: [Motor, Ano, Quilometragem, Zero_km, Acessórios, Valor]
# Index: []
